# %%
# %load_ext autoreload
# %autoreload 2

# %%
from visual_functions import *

# %%
# load data and add new columns if needed
loc = '../data/spotify_tracks.csv'
tracks = make_df(loc)
# Out:
# Added 'duration_s' column
# Added 'year' column

# %% [markdown]
# # Dataset

# %%
make_barplot(
    df = tracks,
    year = (2000,2021),
    popularity = (0,100),
#     save=True,
#     save_name='no_tracks_year_2000-2021_pop_0-100'
)

# %%
make_barplot(
    df = tracks,
    year = (1980,2021),
    popularity = (0,100),
    tick_rotation = True
)

# %% [markdown]
# # General Visuals

# %%
make_line(
    df = tracks,
    year = (2000,2021),
    popularity = (0,100),
#     save=True,
#     save_name='avg_duration_year_2000-2021_pop_0-100'
)

# %%
make_hist(
    df = tracks,
    year = (2000,2021),
    popularity = (0,100),
    bins = 150,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='year_2000-2021_pop_0-100'
)
# Out:
# (2000, 2021) tracks: 211328

# %%
make_hist(
    df = tracks,
    year = (2010,2015),
    popularity = (60,100),
    bins = 100,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='year_2010-2015_pop_60-100'
)
# Out:
# (2010, 2015) tracks: 5073

# %%
make_hist(
    df = tracks,
    year = (2016,2021),
    popularity = (70,100),
    bins = 100,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='year_2015-2021_pop_70-100'
)
# Out:
# (2016, 2021) tracks: 4568

# %% [markdown]
# # "Lo-Fi Effect"

# %%
make_hist(
    df = tracks,
    year = (2020,2021),
    popularity = (0,100),
    bins = 100,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='lofi_year_2020-2021_pop_0-100'
)
# Out:
# (2020, 2021) tracks: 20170

# %%
make_hist(
    df = tracks,
    year = (2020,2021),
    popularity = (0,30),
    bins = 60,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='lofi_year_2020-2021_pop_0-30'
)
# Out:
# (2020, 2021) tracks: 5930

# %%
make_hist(
    df = tracks,
    year = (2020,2021),
    popularity = (30,60),
    bins = 60,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='lofi_year_2020-2021_pop_30-60'
)
# Out:
# (2020, 2021) tracks: 8939

# %%
make_hist(
    df = tracks,
    year = (2020,2021),
    popularity = (60,100),
    bins = 60,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='lofi_year_2020-2021_pop_60-100'
)
# Out:
# (2020, 2021) tracks: 5799

# %%
make_hist(
    df = tracks,
    year = (2006,2013),
    popularity = (0,60),
    bins = 100,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='lofi_year_2006-2013_pop_0-60'
)
# Out:
# (2006, 2013) tracks: 71861

# %%
make_hist(
    df = tracks,
    year = (2014,2021),
    popularity = (0,60),
    bins = 100,
    cutoff = 600,
    xlim = [20,530],
#     save=True,
#     save_name='lofi_year_2014-2021_pop_0-60'
)
# Out:
# (2014, 2021) tracks: 70891
